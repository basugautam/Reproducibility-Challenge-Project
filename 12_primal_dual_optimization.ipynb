# %% [markdown]
# <a href="https://colab.research.google.com/github/basugautam/Reproducibility-Challenge-Project/blob/Architecture-Files/12_primal_dual_optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

# Upload a file from local storage
uploaded = files.upload()

# Check uploaded file
for filename in uploaded.keys():
    print(f"Uploaded file: {filename}")
# Out:
#      <input type="file" id="files-a81b23f7-b5a7-433c-95ed-8593a1e70bf3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a81b23f7-b5a7-433c-95ed-8593a1e70bf3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
from scipy.optimize import minimize

# Example objective function for forecasting error minimization
def objective(params, X, y):
    forecast = np.dot(X, params)  # Linear combination for forecasting
    error = np.sum((y - forecast) ** 2)  # Squared error
    return error  # Minimize this

# Example constraints (e.g., keeping forecasted values within ±10% range)
def constraint(params):
    return 0.1 - np.abs(params[0])  # Ensure optimization respects limits

# Assuming 'df' has a 'feature' column and a 'target' column
X = df[['feature']].values  # Replace 'feature' with actual column name
y = df['target'].values     # Replace 'target' with actual column name

# Initial guess for optimization
initial_params = np.ones(X.shape[1])

# Define constraints as a dictionary
constraints = {'type': 'ineq', 'fun': constraint}

# Run optimization using Primal-Dual approach
result = minimize(objective, initial_params, args=(X, y), constraints=constraints)

# Output optimized parameters
print("Optimized Parameters:", result.x)

# %%
from sklearn.metrics import mean_squared_error

# Forecasted values using the optimized parameters
forecasted_values = np.dot(X, result.x)

# Calculate RMSE (Root Mean Squared Error)
rmse = np.sqrt(mean_squared_error(y, forecasted_values))

print(f"Optimized Forecast RMSE: {rmse}")
